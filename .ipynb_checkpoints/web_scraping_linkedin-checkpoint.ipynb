# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd

options=webdriver.ChromeOptions()
options.add_argument('--incognito')
driver=webdriver.Chrome(options=options)
driver.get('https://www.linkedin.com/uas/login')
driver.maximize_window()

username = driver.find_element_by_id('username')
username.send_keys('your_username')
password = driver.find_element_by_id('password')
password.send_keys('your_password')
log_in_button = driver.find_element_by_class_name('from__button--floating')
log_in_button.click()


urls=['https://www.linkedin.com/company/alicorp-saa/posts/?feedView=all',
       'https://www.linkedin.com/company/backus/posts/?feedView=all',
       'https://www.linkedin.com/showcase/linkedin-noticias-america-latina/posts/?feedView=all']

data={
    "name": [],
    "date": [],
    "post": [],
    "likes": [],
    "count_posts":[]
}

for url in urls:
    driver.get(url)
    for i in range(max(0,10)): # here you will need to tune to see exactly how many scrolls you need
        driver.execute_script('window.scrollBy(0, 500)')
        sleep(1)
    
    src=driver.page_source
    soup=BeautifulSoup(src, 'html.parser')
    posts = driver.find_elements_by_xpath('//div[@class="occludable-update ember-view"]')
    
    count_posts = len(posts) -1
    for names, dates, likes, posts in zip(soup.find_all('div',{'class':'display-flex feed-shared-actor display-flex feed-shared-actor--with-control-menu ember-view'}),
                                        soup.find_all('div',{"class":"display-flex feed-shared-actor display-flex feed-shared-actor--with-control-menu ember-view"}),
                                        soup.find_all('div',{'class':'social-details-social-activity update-v2-social-activity'}),
                                        soup.find_all('div',{'class':"occludable-update ember-view"})):


        name = names.find('span',{'class':'feed-shared-actor__title'}).get_text().strip()
        date = dates.find('span',{'class':'visually-hidden'}).get_text().strip()

        if name and date:
            print('name: ' +name.strip())
            print('date: ' +date.strip())
            data["name"].append(name)                
            data["date"].append(date)              

        try:
            post = posts.find('div',{'class':"feed-shared-update-v2__description-wrapper ember-view"}).span.get_text().strip()   

            if post:
                print('post: ' +post.strip())                       
                data["post"].append(post)

        except Exception as e:
                print('post: ' +'')
                data["post"].append('')
        try:
            likes = likes.find('span',{'class':'v-align-middle social-details-social-counts__reactions-count'}).get_text().strip()

            if likes:
                print('likes: ' +likes)        
                data["likes"].append(likes)                            

        except Exception as e:
                print('likes: ' +'0')        
                data["likes"].append('')     
        print('count_posts: ' +str(count_posts))
        data["count_posts"].append(count_posts)
        print('*'*40)
    print('='*120)
    print('\n')
driver.close()
# Out:
# name: Alicorp
# date: 3 days ago
# post: #AlimentamosUnMañanaMejor en todos los países donde estamos presentes y seguiremos trabajando por ello. Cuéntanos qué te gustaría conocer acerca de nosotros y nuestras operaciones.
# likes: 250
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 1 week ago
# post: Nuestro equipo de Desarrollo Tecnológico - Proyectos de la Vicepresidencia de Supply Chain se presentó al #PMOGlobalAwards, promovido por el PMO Global Alliance con sede en Inglaterra.  En este evento, presentaron el modelo de gestión a través del cual implementamos los principales proyectos industriales de Alicorp en todos los países donde estamos presente. ¡Felicitamos a nuestro equipo que nos acompaña a Alimentar un Mañana Mejor! Conoce más acerca del concurso ingresando a: https://lnkd.in/dfbE2sd
# likes: 422
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 1 week ago
# post: Frente a un año impactado por la emergencia sanitaria como en 2020, desde Alicorp mantuvimos nuestro triple compromiso: mantener el abastecimiento del mercado, cuidar de nuestros colaboradores y apoyar a quienes más lo necesitan. Como resultado, la compañía mantuvo un crecimiento estable. En este contexto la innovación y la transformación digital han sido claves para reaccionar de forma ágil y flexible. Seguimos unidos y trabajando para #AlimentarUnMañanaMejor.Conoce nuestros resultados aquí:
# likes: 858
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 1 week ago
# post: Si tienes una entrevista virtual próximamente o conoces a alguien que vaya a pasar por este proceso, mira el siguiente video. Hemos seleccionado algunos tips con los que puedes llevar a cabo una entrevista virtual exitosa. Si tienes algún otro consejo, compártelo en los comentarios. #AlimentamosUnMañanaMejor.
# likes: 885
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 3 weeks ago
# post: ¡Nos sumamos a #RespiraPeru! Junto a otras empresas e instituciones, acompañamos la entrega del primer lote de 880 respiradores mecánicos. Seguiremos unidos contra la pandemia, ayudando a reforzar nuestro sistema de salud.
# likes: 1,039
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 2 weeks ago
# post: Nuestro VP de Consumo Masivo Internacional, Jose Antonio Cabrera,  lleva más de 20 años en la mentoría, como mentor y también como mentee. En este artículo reflexiona sobre la importancia de este proceso para el crecimiento profesional y personal de ambas partes. Léelo aquí 👇
# likes: 96
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 3 weeks ago
# post: Si quieres ser parte de Alicorp, ten en cuenta nuestros canales oficiales de postulación. Aquí siempre encontrarás nuestras convocatorias recientes.¡Presta mucha atención a las recomendaciones que brindamos al final del video! Acompáñanos a seguir alimentando un mañana mejor.
# likes: 614
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 2 weeks ago
# post: Junto a Soluciones Empresariales contra la Pobreza, nos sumamos para ayudar en la lucha contra la COVID - 19. #YoPongoElHombro #YoMeVacuno #SumamosTodos.
# likes: 465
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 2 weeks ago
# post: Juntos siempre podemos lograr mucho más. El 2020 no fue un año fácil pero nos llena de satisfacción haber contribuido a generar valor y bienestar a través de nuestras iniciativas #AyudaAlQueAyuda y #CrecemosJuntos Agradecemos a Merco RSE, por el reconocimiento como la empresa con mayor responsabilidad social durante la pandemia. Renovamos nuestro compromiso con nuestros clientes, consumidores, colaboradores y comunidades de continuar realizando acciones que permitan alimentar un mañana mejor.
# likes: 429
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 2 weeks ago
# post: Culminamos nuestro IV Congreso de Recursos Humanos, un espacio lleno de aprendizajes y reflexión para nuestro equipo, donde nos acompañaron nuestro Key Note Speaker Roger Martin, Cecilia Illonka Pinzón Reyes como parte de Korn Ferry, SIT Innovation - Systematic Inventive Thinking ®, y nuestro Director de Transformación Digital, Carlos E Zuzunaga. Continuaremos capacitándonos y alimentando nuestro propio desarrollo, como parte fundamental de convertirnos en socios estratégicos para el negocio.
# likes: 221
# count_posts: 10
# ****************************************
# name: Alicorp
# date: 1 month ago
# post: Marcamos un nuevo hito en nuestro camino hacia la transformación digital. ¡Finalizamos nuestro programa Product Management Track! A través de este espacio, co-creado con KURIOS, formamos a los colaboradores de diversas áreas que participan en iniciativas digitales de gran relevancia para Alicorp. Ellos estuvieron acompañados por expertos globales de las empresas más innovadoras en el mundo. Conoce las experiencias y aprendizajes de nuestros Product Managers en el siguiente video:
# likes: 243
# count_posts: 10
# ****************************************
# ========================================================================================================================
#
#
# name: Backus
# date: 2 hours ago
# post: ¡Nuestra #Cusqueña y Rappi están #UnidosEnLaMesa!Para la #ReactivaciónEconómica de más de 2,000 restaurantes, nuestra cerveza y Rappi darán 30% de descuento en los platillos bandera de estos negocios. Adicionalmente, Cusqueña sumará 10,000 botellas de sus variedades para completar la experiencia gastronómica, y se contará con delivery gratis en todos los envíos de esta iniciativa.#FreeDelivery #UnidosXUnPerúMejor
# likes: 42
# count_posts: 8
# ****************************************
# name: Backus
# date: 2 days ago
# post: ¡Gracias a #ElPoderDeLaUnión seguimos en la lucha contra el COVID-19!La semana pasada nuestro equipo llegó a Piura para entregar 600 paquetes de botellas de agua y 15,000 mascarillas a las municipalidades de Castilla, Sullana y Veintiséis de Octubre. Estos donativos serán destinados al personal de dichas instituciones durante la emergencia sanitaria.
# likes: 209
# count_posts: 8
# ****************************************
# name: Backus
# date: 2 days ago
# post: ¡Nos enorgullece anunciar a los ganadores del Fondo Concursable Voluntariado 2021! Este año más de 110 iniciativas sociales participaron, buscando impactar positivamente en el desarrollo del país, a través de propuestas disruptivas y por medio del voluntariado. Conoce a los emprendimientos ganadores aquí. ⬇
# likes: 123
# count_posts: 8
# ****************************************
# name: Backus
# date: 2 weeks ago
# post: Gracias al Banco de Alimentos Perú por su noble labor. Orgullosos de ser un aliado permanente en la lucha por un país sin hambre.
# likes: 1,013
# count_posts: 8
# ****************************************
# name: Backus
# date: 1 week ago
# post: 🚨 ¡ATENCIÓN! Hemos identificado nuevas modalidades de estafa para convocatorias laborales, recuerda que:🔺 Nuestros únicos canales de reclutamiento y selección formal son: nuestras redes sociales oficiales (Facebook y LinkedIn), Bumeran y Computrabajo.🔺 Backus NO COBRA por ningún proceso de selección ni tampoco solicitamos datos personales sensibles por medio de canales como Whatsapp.🔺 Backus no realiza ventas públicas de camiones o transporte.Ayudanos a compartir esta información y evitemos estafas.
# likes: 150
# count_posts: 8
# ****************************************
# name: Backus
# date: 2 weeks ago
# post: ¡Presentamos a los cuatro finalistas del #InnovationDay2021!Las empresas seleccionadas desarrollarán soluciones en los pilares de Green logistics, Almacenaje, Tecnología y Transporte internacional, buscando transformar, innovar y reinventar nuestra logística.Agradecemos a los más de 100 participantes que postularon por su acogida. Los invitamos a mantenerse conectados a nuestras redes sociales para más novedades.
# likes: 105
# count_posts: 8
# ****************************************
# name: Backus
# date: 2 weeks ago
# post: Por noveno año consecutivo formamos parte del TOP 3 de las empresas peruanas más responsables y mantenemos nuestro liderazgo en el Sector Bebidas, en el Ranking Merco Responsabilidad y Gobierno Corporativo 2020.Recibir este reconocimiento en el contexto que vivimos, nos llena de orgullo y motiva a seguir trabajando unidos por un Perú mejor.
# likes: 431
# count_posts: 8
# ****************************************
# name: Backus
# date: 1 month ago
# post: ¡Nos sumamos al Banco de Alimentos Perú para ser parte de la lucha contra el hambre!Este 2021, el apoyo debe venir de todas las fuentes posibles. #UnidosPorUnPerúMejor
# likes: 438
# count_posts: 8
# ****************************************
# name: Backus
# date: 3 weeks ago
# post: ¡Aún estas a tiempo para formar parte de la nueva generación de Young Talent Experience! En Backus seleccionamos, desarrollamos y retenemos a personas que, como Francisco, pueden ser mejores que nosotros. Si eres universitario recién egresado (máximo 6 meses) o a punto de egresar de alguna ingeniería o carrera relacionada con la industria de bebidas, a quien les apasiona la cerveza, ¡postula ya! ¡Date prisa!¡La convocatoria cierra el 6 de febrero! Ingresa a: http://bit.ly/3chdsMz
# likes: 689
# count_posts: 8
# ****************************************
# ========================================================================================================================
#
#
# name: LinkedIn Noticias América Latina
# date: 57 minutes ago
# post: En el mundo de las finanzas se conoce como la “teoría del más tonto” a la que postula que siempre ganarás dinero si compras una acción sobrevalorada, porque habrá “un tonto” dispuesto a pagar más. Es una teoría muy riesgosa que suelen aplicar los inversores cuando hay “burbujas” en el mercado, como la de las .com o la actual de GameStop. Su primera falla es que puede que no surja un comprador y quedes como "el tonto". Y luego, la realidad es que hay más de un iluso, y que generalmente son más los que quedan como "tontos" que los que ganan con esta estrategia. LINK: https://lnkd.in/drEVeZG✍🏼 : LinkedIn Noticias📸 : Getty Images
# likes: 4
# count_posts: 9
# ****************************************
# name: LinkedIn Noticias América Latina
# date: 1 hour ago
# post: La seguridad psicológica es un concepto de los ’60 que cobró fuerza en los ’90 para referir a ambientes y relaciones en los que las personas temen hablar, mostrarse como son y dar feedback. Esto lleva a un agotamiento emocional que decanta en “burnout”. Un grave error es pensar que prevenir ese desgaste es un problema personal, porque en realidad es consecuencia de la intersección de las personas, el lugar de trabajo y su cultura. Los líderes pueden crear espacios que cultiven la seguridad psicológica si escuchan a los empleados y no temen reconocer sus propias falencias. LINK: https://lnkd.in/d_2euDu✍🏼 : LinkedIn Noticias📸 : Getty Images
# likes: 3
# count_posts: 9
# ****************************************
# name: LinkedIn Noticias América Latina
# date: 1 hour ago
# post: En una conferencia que brindó en Francia en 2007, el empresario Bill Gates dijo que la habilidad más importante que deben desarrollar los emprendedores es la de saber vender. Esta capacidad puede hacer la diferencia entre el éxito y el fracaso, ya que es necesario no solo convencer a los consumidores sino también a los proveedores de crédito, los inversores, e incluso a los talentos, para que trabajen en la compañía. Conformar el equipo de trabajo correcto para crecer es un factor crítico. Por eso, dijo el magnate, debes poder vender tu visión de liderazgo. LINK: https://lnkd.in/d6Ywb-D✍🏼 : LinkedIn Noticias📸 : Getty Images
# likes: 3
# count_posts: 9
# ****************************************
# name: LinkedIn Noticias América Latina
# date: 1 hour ago
# post: Estudios recientes mostraron que el coeficiente intelectual de las personas puede ser hasta 13 puntos mayor en momentos en los que son optimistas o no están preocupadas. Ser positivos nos hace más inteligentes, porque cambia nuestro esquema mental de la escasez (vivimos pensando en lo que no tenemos o nos falta) a la abundancia y libera espacio en nuestro cerebro para pensar en otras posibilidades. Para lograrlo, conviene enfocarse en lo que tenemos, rodearnos de personas positivas y practicar la gratitud. Por último, vale la pena entrenar a la mente para que identifique oportunidades inesperadas. LINK: https://lnkd.in/dWKD55v✍🏼 : LinkedIn Noticias📸 : Getty Images
# likes: 8
# count_posts: 9
# ****************************************
# name: LinkedIn Noticias América Latina
# date: 1 week ago
# post: #ENCUESTA El inicio del año es un momento clave en la búsqueda de empleo, tanto para aquellos que han perdido su trabajo por la pandemia como para quienes se fijaron como meta lograr un cambio laboral en 2021. En tu opinión, ¿cuál es el mejor consejo profesional para las personas que están buscando trabajo?
# likes: 568
# count_posts: 9
# ****************************************
# name: LinkedIn Noticias América Latina
# date: 2 days ago
# post: Hay juegos de mente que puedes utilizar para mejorar tus habilidades como líder. Uno de ellos, conocido como “Y si…” (What if? en inglés), prepara el cerebro para situaciones inesperadas. Requiere preguntarse qué harías si ocurre algo inusual, como un terremoto. Otro de los juegos es “Si/cuando”: piensa en una situación posible, como por ejemplo “si dos de mis colaboradores contraen Covid-19…” y reemplaza la palabra “si” por “cuando”, para anticiparte al problema. Por último, WOOP es un juego para el cual debes pensar en tus deseos, resultados, obstáculos y un plan para llegar al objetivo. LINK: https://lnkd.in/drDsZNd✍🏼 : LinkedIn Noticias📸 : Getty Images
# likes: 1,179
# count_posts: 9
# ****************************************
# name: LinkedIn Noticias América Latina
# date: 4 days ago
# post: Todos conocemos los efectos del envejecimiento sobre el aspecto físico y la vitalidad, pero ahora los científicos están descubriendo nuevos cambios más misteriosos que acompañan a la edad. Aseguran que ocurre una modificación gradual de nuestra personalidad que nos vuelve más conscientes, agradables y menos neuróticos. Disminuye el riesgo de comportamientos antisociales o criminales, aumenta la fuerza de voluntad y mejora el sentido del humor. Con el paso de los años nos volvemos emocionalmente más estables. Al ver que esta maduración de la personalidad es universal, algunos científicos postulan que es una consecuencia evolutiva. LINK: https://lnkd.in/dJtxteK✍🏼 : LinkedIn Noticias📸 : Getty Images
# likes: 90
# count_posts: 9
# ****************************************
# name: LinkedIn Noticias América Latina
# date: 2 weeks ago
# post: #ENCUESTA Las restricciones en empresas y bares han hecho que más de uno sacrifique la pausa del #desayuno o café en el trabajo. Muchos se han acostumbrado a desayunar frente a la pantalla de la computadora o directamente se saltan esa comida, pese al impacto negativo en la salud y en la moral. ¿Cuál es tu caso? Participa en nuestra encuesta y cuéntanos cómo la pandemia ha cambiado tus hábitos.
# likes: 102
# count_posts: 9
# ****************************************
# name: LinkedIn Noticias América Latina
# date: 3 weeks ago
# post: El diario español "El Mundo" publicó que el jugador del Barcelona Leo Messi renovó en 2017 su contrato por 555,2 millones de euros por cuatro años. Muchas empresas tienen sus "Messis corporativos", ¿cómo crees que debería estructurarse el salario de los grandes talentos? Participa en la encuesta y justifica tu respuesta en los comentarios.
# likes: 568
# count_posts: 9
# ****************************************
# name: LinkedIn Noticias América Latina
# date: 1 month ago
# post: ¡Te damos la bienvenida a LinkedIn! ¿No sabes por dónde empezar? ¡Sigue a las Top Voices 2020 de América Latina para obtener el mejor contenido publicado en la plataforma! De esta manera, aumentan las posibilidades de expandir tu red y descubrir nuevas oportunidades de empleo.Alejandra Mustakis - https://lnkd.in/gPJqqNVJahir López - https://lnkd.in/gN8yetAJavier Calzolari - https://lnkd.in/gyETsyGLauren Kressler - https://lnkd.in/gGf93drLina Maria Echeverri - https://lnkd.in/gQzU9BWMartin Pettinati - https://lnkd.in/gBF_twzMelina Jajamovich - https://lnkd.in/gTt2EWsRafael Zavala Batlle - https://lnkd.in/gdTfgtiVanessa Carabelli - https://lnkd.in/gP_7x_DVincent's Santolo - https://lnkd.in/gfx6CzJNo te olvides de seguir las páginas de LinkedIn Noticias América Latina y LinkedIn Noticias México para acceder a las noticias y reflexiones que necesitas para mantenerte informado.LinkedIn Noticias América Latina - https://lnkd.in/linkedinnoticiaslatamLinkedIn Noticias México - https://lnkd.in/linkedinnoticiasmexico
# likes: 276
# count_posts: 9
# ****************************************
# ========================================================================================================================

# %%
df=pd.DataFrame(data)
df
# Out:
#                                 name            date  \
# 0                            Alicorp      3 days ago
# 1                            Alicorp      1 week ago
# 2                            Alicorp      1 week ago
# 3                            Alicorp      1 week ago
# 4                            Alicorp     3 weeks ago
# 5                            Alicorp     2 weeks ago
# 6                            Alicorp     3 weeks ago
# 7                            Alicorp     2 weeks ago
# 8                            Alicorp     2 weeks ago
# 9                            Alicorp     2 weeks ago
# 10                           Alicorp     1 month ago
# 11                            Backus     2 hours ago
# 12                            Backus      2 days ago
# 13                            Backus      2 days ago
# 14                            Backus     2 weeks ago
# 15                            Backus      1 week ago
# 16                            Backus     2 weeks ago
# 17                            Backus     2 weeks ago
# 18                            Backus     1 month ago
# 19                            Backus     3 weeks ago
# 20  LinkedIn Noticias América Latina  57 minutes ago
# 21  LinkedIn Noticias América Latina      1 hour ago
# 22  LinkedIn Noticias América Latina      1 hour ago
# 23  LinkedIn Noticias América Latina      1 hour ago
# 24  LinkedIn Noticias América Latina      1 week ago
# 25  LinkedIn Noticias América Latina      2 days ago
# 26  LinkedIn Noticias América Latina      4 days ago
# 27  LinkedIn Noticias América Latina     2 weeks ago
# 28  LinkedIn Noticias América Latina     3 weeks ago
# 29  LinkedIn Noticias América Latina     1 month ago
#
#                                                  post  likes  count_posts
# 0   #AlimentamosUnMañanaMejor en todos los países ...    250           10
# 1   Nuestro equipo de Desarrollo Tecnológico - Pro...    422           10
# 2   Frente a un año impactado por la emergencia sa...    858           10
# 3   Si tienes una entrevista virtual próximamente ...    885           10
# 4   ¡Nos sumamos a #RespiraPeru! Junto a otras emp...  1,039           10
# 5   Nuestro VP de Consumo Masivo Internacional, Jo...     96           10
# 6   Si quieres ser parte de Alicorp, ten en cuenta...    614           10
# 7   Junto a Soluciones Empresariales contra la Pob...    465           10
# 8   Juntos siempre podemos lograr mucho más. El 20...    429           10
# 9   Culminamos nuestro IV Congreso de Recursos Hum...    221           10
# 10  Marcamos un nuevo hito en nuestro camino hacia...    243           10
# 11  ¡Nuestra #Cusqueña y Rappi están #UnidosEnLaMe...     42            8
# 12  ¡Gracias a #ElPoderDeLaUnión seguimos en la lu...    209            8
# 13  ¡Nos enorgullece anunciar a los ganadores del ...    123            8
# 14  Gracias al Banco de Alimentos Perú por su nobl...  1,013            8
# 15  🚨 ¡ATENCIÓN! Hemos identificado nuevas modalid...    150            8
# 16  ¡Presentamos a los cuatro finalistas del #Inno...    105            8
# 17  Por noveno año consecutivo formamos parte del ...    431            8
# 18  ¡Nos sumamos al Banco de Alimentos Perú para s...    438            8
# 19  ¡Aún estas a tiempo para formar parte de la nu...    689            8
# 20  En el mundo de las finanzas se conoce como la ...      4            9
# 21  La seguridad psicológica es un concepto de los...      3            9
# 22  En una conferencia que brindó en Francia en 20...      3            9
# 23  Estudios recientes mostraron que el coeficient...      8            9
# 24  #ENCUESTA El inicio del año es un momento clav...    568            9
# 25  Hay juegos de mente que puedes utilizar para m...  1,179            9
# 26  Todos conocemos los efectos del envejecimiento...     90            9
# 27  #ENCUESTA Las restricciones en empresas y bare...    102            9
# 28  El diario español "El Mundo" publicó que el ju...    568            9
# 29  ¡Te damos la bienvenida a LinkedIn! ¿No sabes ...    276            9
